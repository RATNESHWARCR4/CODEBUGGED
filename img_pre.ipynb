# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
img_path="C:/Users/PRANSHU CHOUBEY/Desktop/Ratneshwar/CODEBUGGED_TEST/B4120C1_img_01.jpeg"

# %%
img=cv2.imread(img_path)

# %%
plt.imshow(img)
plt.show()

# %%
img=np.array(img)

# %%
img = img[1000:1750,1200:3200]

# %%
file_img="./abc.jpeg"

# %%
cv2.imwrite(file_img, img)
# Out:
# True
